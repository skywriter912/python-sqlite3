# %%
import json
import sqlite3

# %%
conn = sqlite3.connect('rosterdb_task.sqlite')
cur = conn.cursor()

# %%
cur.executescript('''
DROP TABLE IF EXISTS User;
DROP TABLE IF EXISTS Member;
DROP TABLE IF EXISTS Course;

CREATE TABLE User (
    id     INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    name   TEXT UNIQUE
);

CREATE TABLE Course (
    id     INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    title  TEXT UNIQUE
);

CREATE TABLE Member (
    user_id     INTEGER,
    course_id   INTEGER,
    role        INTEGER,
    PRIMARY KEY (user_id, course_id)
)
''')

# %%
fname = 'roster_data.json'
#   [ "Charley", "si110", 1 ],
#   [ "Mea", "si110", 0 ],

# %%
str_data = open(fname).read()
json_data = json.loads(str_data)

for entry in json_data:

    name = entry[0];
    title = entry[1];
    role = entry[2];

    print((name, title, role))

    cur.execute('''INSERT OR IGNORE INTO User (name)
        VALUES ( ? )''', ( name, ) )
    cur.execute('SELECT id FROM User WHERE name = ? ', (name, ))
    user_id = cur.fetchone()[0]

    cur.execute('''INSERT OR IGNORE INTO Course (title)
        VALUES ( ? )''', ( title, ) )
    cur.execute('SELECT id FROM Course WHERE title = ? ', (title, ))
    course_id = cur.fetchone()[0]

    cur.execute('''INSERT OR REPLACE INTO Member
        (user_id, course_id, role) VALUES ( ?, ?, ? )''',
        ( user_id, course_id, role ) )

    conn.commit()
# Out:
# ('Alanna', 'si110', 1)
# ('Lillyanne', 'si110', 0)
# ('Ryley', 'si110', 0)
# ('Sukhvir', 'si110', 0)
# ('Kate', 'si110', 0)
# ('Kieryn', 'si110', 0)
# ('Ben', 'si110', 0)
# ('Merin', 'si110', 0)
# ('Rhienna', 'si110', 0)
# ('Kendyn', 'si110', 0)
# ('Prabhjot', 'si110', 0)
# ('Zeenat', 'si110', 0)
# ('Robbie', 'si110', 0)
# ('Evan', 'si110', 0)
# ('Cady', 'si110', 0)
# ('Charlay', 'si110', 0)
# ('Hattie', 'si110', 0)
# ('Calan', 'si110', 0)
# ('Jacqueline', 'si110', 0)
# ('Zubair', 'si110', 0)
# ('Jacques', 'si110', 0)
# ('Emilylee', 'si110', 0)
# ('Jaise', 'si110', 0)
# ('Dillan', 'si110', 0)
# ('Zunera', 'si110', 0)
# ('Jenson', 'si110', 0)
# ('Haghdann', 'si106', 1)
# ('Apisai', 'si106', 0)
# ('Sol', 'si106', 0)
# ('Xavier', 'si106', 0)
# ('Kellsie', 'si106', 0)
# ('Weronika', 'si106', 0)
# ('Oluwalayomi', 'si106', 0)
# ('Amylea', 'si106', 0)
# ('Ibraheem', 'si106', 0)
# ('Rehaan', 'si106', 0)
# ('Colt', 'si106', 0)
# ('Azlan', 'si106', 0)
# ('Zuzu', 'si106', 0)
# ('Hollye', 'si106', 0)
# ('Aeryn', 'si106', 0)
# ('Lynsie', 'si106', 0)
# ('Madilyn', 'si106', 0)
# ('Kelly', 'si106', 0)
# ('Aine', 'si106', 0)
# ('Oluwatimilehin', 'si106', 0)
# ('Zachary', 'si106', 0)
# ('Kimi', 'si106', 0)
# ('Calan', 'si106', 0)
# ('Allister', 'si106', 0)
# ('Leigh', 'si106', 0)
# ('Tiona', 'si106', 0)
# ('Capree', 'si106', 0)
# ('Lawlyn', 'si106', 0)
# ('Jeannie', 'si106', 0)
# ('Shauntel', 'si106', 0)
# ('Maeghan', 'si106', 0)
# ('Sylvie', 'si106', 0)
# ('Peggy', 'si106', 0)
# ('Pipa', 'si106', 0)
# ('Kobe', 'si106', 0)
# ('Maiya', 'si106', 0)
# ('Graidi', 'si106', 0)
# ('Lina', 'si106', 0)
# ('Calla', 'si106', 0)
# ('Lumi', 'si106', 0)
# ('Tubagus', 'si106', 0)
# ('Luic', 'si106', 0)
# ('Raphael', 'si106', 0)
# ('Dermot', 'si106', 0)
# ('Rehaan', 'si206', 1)
# ('Cruz', 'si206', 0)
# ('Alaa', 'si206', 0)
# ('Clarisse', 'si206', 0)
# ('Sullivan', 'si206', 0)
# ('Sofiane', 'si206', 0)
# ('Balian', 'si206', 0)
# ('Andra', 'si206', 0)
# ('Garren', 'si206', 0)
# ('Dillon', 'si206', 0)
# ('Possum', 'si206', 0)
# ('Sephiroth', 'si206', 0)
# ('Rohaan', 'si206', 0)
# ('Kirsten', 'si206', 0)
# ('Karolina', 'si206', 0)
# ('Jaxson', 'si206', 0)
# ('Fern', 'si206', 0)
# ('Kalvin', 'si206', 0)
# ('Declyn', 'si206', 0)
# ('Samarjit', 'si206', 0)
# ('Sidra', 'si206', 0)
# ('Kerryanne', 'si206', 0)
# ('Kyra', 'si206', 0)
# ('Carlie', 'si206', 0)
# ('Sonia', 'si206', 0)
# ('Claire', 'si206', 0)
# ('Joude', 'si206', 0)
# ('Nisha', 'si206', 0)
# ('Shakira', 'si206', 0)
# ('Dimitri', 'si206', 0)
# ('Rachael', 'si206', 0)
# ('Manar', 'si206', 0)
# ('Anastazja', 'si206', 0)
# ('Kiya', 'si206', 0)
# ('Tay', 'si206', 0)
# ('Shaw', 'si206', 0)
# ('Elyse', 'si206', 0)
# ('Sereen', 'si206', 0)
# ('Mayra', 'si206', 0)
# ('Lekiesha', 'si206', 0)
# ('Salman', 'si206', 0)
# ('Abhisumant', 'si206', 0)
# ('Roray', 'si206', 0)
# ('Elissa', 'si206', 0)
# ('Fodeba', 'si206', 0)
# ('Firaaz', 'si206', 0)
# ('Musa', 'si206', 0)
# ('Oban', 'si206', 0)
# ('Anthony', 'si206', 0)
# ('Alyia', 'si206', 0)
# ('Girls', 'si206', 0)
# ('Carrich', 'si301', 1)
# ('Struan', 'si301', 0)
# ('Fatimah', 'si301', 0)
# ('Gretchen', 'si301', 0)
# ('Lacy', 'si301', 0)
# ('Pearse', 'si301', 0)
# ('Deryn', 'si301', 0)
# ('Roman', 'si301', 0)
# ('Lloyde', 'si301', 0)
# ('Aaraa', 'si301', 0)
# ('Carlynn', 'si301', 0)
# ('Dua', 'si301', 0)
# ('Gregory', 'si301', 0)
# ('Harneet', 'si301', 0)
# ('Abdulkadir', 'si301', 0)
# ('Guerin', 'si301', 0)
# ('Risa', 'si301', 0)
# ('Corey', 'si301', 0)
# ('Celina', 'si301', 0)
# ('Likiesha', 'si301', 0)
# ('Ayla', 'si301', 0)
# ('Zenah', 'si301', 0)
# ('Dubhlinn', 'si301', 0)
# ('Cameryn', 'si301', 0)
# ('Trent', 'si301', 0)
# ('Lillie', 'si301', 0)
# ('Frazer', 'si301', 0)
# ('Mustapha', 'si301', 0)
# ('Kenzi', 'si301', 0)
# ('Eilish', 'si301', 0)
# ('Ceira', 'si301', 0)
# ('Tobie', 'si301', 0)
# ('Taylor', 'si301', 0)
# ('Kareena', 'si301', 0)
# ('Kharli', 'si301', 0)
# ('Carron', 'si301', 0)
# ('Lilliarna', 'si301', 0)
# ('Sarabeth', 'si301', 0)
# ('Sonia', 'si301', 0)
# ('Sharmin', 'si301', 0)
# ('Rai', 'si301', 0)
# ('Cate', 'si310', 1)
# ('Lenzy', 'si310', 0)
# ('Lilia', 'si310', 0)
# ('Franciszek', 'si310', 0)
# ('Frankie', 'si310', 0)
# ('Lianna', 'si310', 0)
# ('Kaelan', 'si310', 0)
# ('Romana', 'si310', 0)
# ('Lauchlin', 'si310', 0)
# ('Felicia', 'si310', 0)
# ('Valentina', 'si310', 0)
# ('Milly', 'si310', 0)
# ('Martyn', 'si310', 0)
# ('Annabel', 'si310', 0)
# ('Abbey', 'si310', 0)
# ('Lynsie', 'si310', 0)
# ('Ellice', 'si310', 0)
# ('Maighdlin', 'si310', 0)
# ('Darrell', 'si310', 0)
# ('Darrel', 'si310', 0)
# ('Garry', 'si310', 0)
# ('Kate', 'si310', 0)
# ('Ahoua', 'si310', 0)
# ('Dawn', 'si310', 0)
# ('Benn', 'si310', 0)
# ('Laia', 'si310', 0)
# ('Jewel', 'si310', 0)
# ('Rachael', 'si310', 0)
# ('Cailie', 'si310', 0)
# ('Aliesha', 'si310', 0)
# ('Emir', 'si310', 0)
# ('Coben', 'si310', 0)
# ('Arman', 'si310', 0)
# ('Courtneylee', 'si310', 0)
# ('Kayliegh', 'si310', 0)
# ('Cacie', 'si310', 0)
# ('Isaiah', 'si310', 0)
# ('Malachy', 'si310', 0)
# ('Sorcha', 'si310', 0)
# ('Caie', 'si310', 0)
# ('Martine', 'si334', 1)
# ('Nuala', 'si334', 0)
# ('Kohen', 'si334', 0)
# ('Manar', 'si334', 0)
# ('Momooreoluwa', 'si334', 0)
# ('Colby', 'si334', 0)
# ('Ameerah', 'si334', 0)
# ('Kacper', 'si334', 0)
# ('Alistar', 'si334', 0)
# ('Verity', 'si334', 0)
# ('Rihana', 'si334', 0)
# ('Makenzie', 'si334', 0)
# ('Moya', 'si334', 0)
# ('Aleishia', 'si334', 0)
# ('Ayla', 'si334', 0)
# ('Joshiah', 'si334', 0)
# ('Msughter', 'si334', 0)
# ('Hareem', 'si334', 0)
# ('Hillary', 'si334', 0)
# ('Leno', 'si334', 0)
# ('Marc', 'si334', 0)
# ('Colm', 'si334', 0)
# ('Rudi', 'si334', 0)
# ('Meara', 'si334', 0)
# ('Lila', 'si334', 0)
# ('Izabella', 'si334', 0)
# ('Milos', 'si334', 0)
# ('Caedyn', 'si334', 0)
# ('Kinsey', 'si334', 0)
# ('Philip', 'si334', 0)
# ('Elliot', 'si334', 0)
# ('Peirce', 'si334', 0)
# ('Sorcha', 'si334', 0)
# ('Aymie', 'si334', 0)
# ('Brynmor', 'si334', 0)
# ('Stacey', 'si334', 0)
# ('Jacob', 'si334', 0)
# ('Kedrick', 'si334', 0)
# ('Coby', 'si334', 0)
# ('Tiana', 'si334', 0)
# ('Kaydyn', 'si334', 0)
# ('Katherine', 'si334', 0)
# ('Anselm', 'si334', 0)
# ('Areeb', 'si334', 0)
# ('Trai', 'si334', 0)
# ('Danika', 'si363', 1)
# ('Halyda', 'si363', 0)
# ('Alf', 'si363', 0)
# ('Alveena', 'si363', 0)
# ('Misba', 'si363', 0)
# ('Eve', 'si363', 0)
# ('Guthrie', 'si363', 0)
# ('Drew', 'si363', 0)
# ('Kevan', 'si363', 0)
# ('Saira', 'si363', 0)
# ('Saranna', 'si363', 0)
# ('Rian', 'si363', 0)
# ('Lawrence', 'si363', 0)
# ('Aelish', 'si363', 0)
# ('Daniel', 'si363', 0)
# ('Haroon', 'si363', 0)
# ('Jock', 'si363', 0)
# ('Maeve', 'si363', 0)
# ('Dalton', 'si363', 0)
# ('Soham', 'si363', 0)
# ('Angelina', 'si363', 0)
# ('Jamielee', 'si363', 0)
# ('Sohaa', 'si363', 0)
# ('Sharmin', 'si363', 0)
# ('Dissanayake', 'si363', 0)
# ('Graham', 'si363', 0)
# ('Amrit', 'si363', 0)
# ('Grant', 'si363', 0)
# ('Joris', 'si364', 1)
# ('Architha', 'si364', 0)
# ('Zen', 'si364', 0)
# ('Aditya', 'si364', 0)
# ('Keo', 'si364', 0)
# ('Johnpaul', 'si364', 0)
# ('Joshiah', 'si364', 0)
# ('Isadora', 'si364', 0)
# ('Rebeka', 'si364', 0)
# ('Oriane', 'si364', 0)
# ('Davy', 'si364', 0)
# ('Vasyl', 'si364', 0)
# ('Keelin', 'si364', 0)
# ('Maisi', 'si364', 0)
# ('Isira', 'si364', 0)
# ('Kera', 'si364', 0)
# ('Moryn', 'si364', 0)
# ('Jonah', 'si364', 0)
# ('Sweet', 'si364', 0)
# ('Rowan', 'si364', 0)
# ('Johnnie', 'si364', 0)
# ('Seumas', 'si364', 0)
# ('Haneeah', 'si364', 0)
# ('Rob', 'si364', 0)
# ('Rhoan', 'si364', 0)
# ('Manas', 'si364', 0)
# ('Nolan', 'si364', 0)
# ('Meryl', 'si364', 0)
# ('Iana', 'si364', 0)
# ('Donnie', 'si364', 0)
# ('Qirui', 'si364', 0)
# ('Jenson', 'si364', 0)
# ('Briony', 'si364', 0)
# ('Shahmir', 'si364', 0)
# ('Tomas', 'si364', 0)
# ('Fauzaan', 'si364', 0)
# ('Hollye', 'si364', 0)
# ('Xanthia', 'si364', 0)
# ('Gjan', 'si364', 0)
# ('Siubhan', 'si364', 0)
# ('Niteesha', 'si364', 0)
# ('Lileidh', 'si364', 0)
# ('Amrita', 'si364', 0)
# ('Shani', 'si364', 0)
# ('Wezi', 'si364', 0)
# ('Isabella', 'si364', 0)
# ('Reynelle', 'si364', 0)
# ('Jaydon', 'si364', 0)
# ('Taliesin', 'si364', 0)
# ('Aibidh', 'si422', 1)
# ('Amilie', 'si422', 0)
# ('Arun', 'si422', 0)
# ('Kamran', 'si422', 0)
# ('Cody', 'si422', 0)
# ('Alesha', 'si422', 0)
# ('Clementine', 'si422', 0)
# ('Franco', 'si422', 0)
# ('Farzad', 'si422', 0)
# ('Dilya', 'si422', 0)
# ('Bronte', 'si422', 0)
# ('Dexter', 'si422', 0)
# ('Suzannah', 'si422', 0)
# ('Carli', 'si422', 0)
# ('Janel', 'si422', 0)
# ('Aseel', 'si422', 0)
# ('Jaise', 'si422', 0)
# ('Shahd', 'si422', 0)
# ('Jasmina', 'si430', 1)
# ('Ash', 'si430', 0)
# ('Micaylah', 'si430', 0)
# ('Kalum', 'si430', 0)
# ('Kaydan', 'si430', 0)
# ('Riha', 'si430', 0)
# ('Tai', 'si430', 0)
# ('Siddhant', 'si430', 0)
# ('Khizar', 'si430', 0)
# ('Kerri', 'si430', 0)
# ('Arisha', 'si430', 0)
# ('Korey', 'si430', 0)
# ('Torran', 'si430', 0)
# ('Celsea', 'si430', 0)
# ('Seamas', 'si430', 0)
# ('Elgin', 'si430', 0)
# ('Alexa', 'si430', 0)
# ('Donnacha', 'si430', 0)
# ('Mohamad', 'si430', 0)
# ('Rubhan', 'si430', 0)
# ('Taen', 'si430', 0)
# ('Cailyn', 'si430', 0)
# ('Cobi', 'si430', 0)
# ('Alyia', 'si430', 0)
# ('Lottie', 'si430', 0)
# ('Heini', 'si430', 0)
# ('Erica', 'si430', 0)
# ('Hussan', 'si430', 0)
# ('Mirrin', 'si430', 0)
# ('Fenn', 'si430', 0)
# ('Micheal', 'si430', 0)
# ('Immanuel', 'si430', 0)
# ('Boab', 'si430', 0)
# ('Romanie', 'si430', 0)
# ('Nick', 'si430', 0)
# ('Kinga', 'si430', 0)
# ('Porter', 'si430', 0)
